# %%
import os
import sys

# Add src as module
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)

from src.julia_set import julia_set
from src.quantum_made_easy import run_circuit_on_aersimulator, run_circuit_on_ibm_least_busy
from math import pi, sqrt
from matplotlib import pyplot as plt
import numpy as np

# %%
from qiskit import QuantumCircuit

# %%
# Create a Quantum Circuit acting on the q register
circuit = QuantumCircuit(1,1)
circuit.ry(pi/2,0)
circuit.tdg(0)

# %%
result = run_circuit_on_aersimulator(circuit)

# %%
circuit = QuantumCircuit(1,1)
circuit.ry(pi/2,0)
circuit.tdg(0)
circuit.measure_all()
result_qc = run_circuit_on_aersimulator(circuit)

# %%
list(result[1])
# Out:
# /tmp/ipykernel_94488/2857973282.py:1: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   list(result[1])
# [(0.7071067811865476+0j), (0.4999999999999999-0.4999999999999999j)]

# %%
z = np.array(list(result[0].values()))*np.sqrt(np.array(list(result_qc[0].values()))**2)

# %%
z0 = list(result[0].values())[0] * np.sqrt(list(result_qc[0].values())[0]**2)
z1 = list(result[0].values())[1] * np.sqrt(list(result_qc[0].values())[1]**2)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /home/pk/projects/HackYeah2023_KNML_TEAM_2_QUANTUM_ART/notebooks/julia_set.ipynb Cell 8 line 2
#       <a href='vscode-notebook-cell:/home/pk/projects/HackYeah2023_KNML_TEAM_2_QUANTUM_ART/notebooks/julia_set.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> z0 = list(result[0].values())[0] * np.sqrt(list(result_qc[0].values())[0]**2)
# ----> <a href='vscode-notebook-cell:/home/pk/projects/HackYeah2023_KNML_TEAM_2_QUANTUM_ART/notebooks/julia_set.ipynb#X34sZmlsZQ%3D%3D?line=1'>2</a> z1 = list(result[0].values())[1] * np.sqrt(list(result_qc[0].values())[1]**2)
#
# IndexError: list index out of range

# %%
z1
# Out:
# 0.9384727478027344

# %%
list(result[1])
# Out:
# /tmp/ipykernel_94488/2857973282.py:1: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   list(result[1])
# [(0.7071067811865476+0j), (0.4999999999999999-0.4999999999999999j)]

# %%
res = julia_set1CN(list(result[1])[1])
# Out:
# /tmp/ipykernel_94488/149634689.py:1: DeprecationWarning: The return type of saved statevectors has been changed from a `numpy.ndarray` to a `qiskit.quantum_info.Statevector` as of qiskit-aer 0.10. Accessing numpy array attributes is deprecated and will result in an error in a future release. To continue using saved result objects as arrays you can explicitly cast them using  `np.asarray(object)`.
#   res = julia_set1CN(list(result[1])[1])

# %%
plt.imshow(res)
plt.show()

# %%
plt.figure(figsize = (10, 10))
plt.pcolormesh(x, y, F, cmap = "magma")
plt.axis('equal')
plt.axis('off')
plt.show()
